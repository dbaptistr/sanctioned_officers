# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv('ServPubSancionados2.csv', encoding= 'latin-1')

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    officialNumber   File ResolutionDate                PublicOfficial  \
# 0               0  12012     2014-09-29       HUMBERTO ADAME CASTILLO
# 1               1  12013     2014-11-03          AGUSTIN TOLEDO GADEA
# 2               2  12013     2017-04-03   GUSTAVO ANTONIO NIEVES DIAZ
# 3               3  12014     2014-11-28  ABUNDIO HERNANDEZ DE LA CRUZ
# 4               4  12014     2014-11-28          CARLOS DAVALOS SOLIS
#
#                    Authority  \
# 0  ORGANO INTERNO DE CONTROL
# 1  ORGANO INTERNO DE CONTROL
# 2  ORGANO INTERNO DE CONTROL
# 3  ORGANO INTERNO DE CONTROL
# 4  ORGANO INTERNO DE CONTROL
#
#                                          Institution  \
# 0                         COMISION NACIONAL FORESTAL
# 1                 INSTITUTO NACIONAL DE CANCEROLOGIA
# 2  INSTITUTO DE SEGURIDAD Y SERVICIOS SOCIALES DE...
# 3  ADMINISTRACION PORTUARIA INTEGRAL DE TAMPICO S...
# 4  ADMINISTRACION PORTUARIA INTEGRAL DE TAMPICO S...
#
# ...

# %%
df.dtypes
# Out:
# officialNumber                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        int64
# ...

# %%
df.rename(columns={'index': 'officialNumber'}, inplace=True)

# %%
conn = sqlite3.connect('officials_data.db')

# %%
df.to_sql('officials_data', conn)
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
pd.read_sql('SELECT * FROM officials_data', conn)
# Out:
#     index  officialNumber   File ResolutionDate  \
# 0       0               0  12012     2014-09-29
# 1       1               1  12013     2014-11-03
# 2       2               2  12013     2017-04-03
# 3       3               3  12014     2014-11-28
# 4       4               4  12014     2014-11-28
# 5       5               5  12014     2015-12-09
# 6       6               6  12014     2017-10-10
# 7       7               7  12015     2015-05-22
# 8       8               8  12015     2015-06-23
# 9       9               9  12015     2015-07-15
# 10     10              10  12015     2015-09-30
# 11     11              11  12015     2015-10-26
# 12     12              12  12015     2015-10-30
# 13     13              13  12015     2016-01-20
# 14     14              14  12015     2016-09-15
# 15     15              15  12015     2017-05-31
# 16     16              16  12016     2016-07-11
# 17     17              17  12016     2016-10-17
# ...
